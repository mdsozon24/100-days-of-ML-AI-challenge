# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsozon24/100-days-of-ML-AI-challenge/blob/main/Data%20processing/CSV_files_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #1. Read CSV from drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/insurance_data.csv')
display(df.head())
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %% [markdown]
# #2. Read CSV with URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/mdsozon24/Price-Prediction-for-Airbnb-Listings/main/airbnb%20dataset.csv"

# %%
response = requests.get(url)
df = pd.read_csv(StringIO(response.text))
df.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#   rating reviews    host_name      host_id                   address  \
# 0   4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.0      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4    New       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# ...

# %% [markdown]
# #3. Read CSV Local computer

# %%
from google.colab import files
import io

# %%
uploaded = files.upload()
df = pd.read_csv(io.BytesIO(uploaded[list(uploaded.keys())[0]]))
# Out:
#      <input type="file" id="files-26685c68-25d3-4e00-a6d6-c6cae2e1bb56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26685c68-25d3-4e00-a6d6-c6cae2e1bb56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#        Name  Age  Roll Sex  Height  Weight    BMI
# 0     Sozon   23    15   M    1.56      63  25.89
# 1   Sharmin   21    16   F    1.01      45  44.11
# 2      Naim   22    17   M    1.65      71  26.08
# 3  Ashraful   26    18   M    1.32      56  32.14
