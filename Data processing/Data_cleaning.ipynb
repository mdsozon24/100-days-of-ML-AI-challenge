# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsozon24/100-days-of-ML-AI-challenge/blob/main/Data%20processing/Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv('drive/MyDrive/Datasets/Diabetes Missing Data.csv')
df.head(15)
# Out:
#     Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0          6    148.0          72.0       35.0            NaN  33.6
# 1          1     85.0          66.0       29.0            NaN  26.6
# 2          8    183.0          64.0        NaN            NaN  23.3
# 3          1     89.0          66.0       23.0           94.0  28.1
# 4          0    137.0          40.0       35.0          168.0  43.1
# 5          5    116.0          74.0        NaN            NaN  25.6
# 6          3     78.0          50.0       32.0           88.0  31.0
# 7         10    115.0           NaN        NaN            NaN  35.3
# 8          2    197.0          70.0       45.0          543.0  30.5
# 9          8    125.0          96.0        NaN            NaN   NaN
# 10         4    110.0          92.0        NaN            NaN  37.6
# 11        10    168.0          74.0        NaN            NaN  38.0
# 12        10    139.0          80.0        NaN            NaN  27.1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(652)

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
(df.isnull().sum().sum()/(df.shape[0]*df.shape[1]))*100
# Out:
# np.float64(9.43287037037037)

# %%
df.dropna()
df
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
# df.drop(columns=['Serum_Insulin'])
df.drop(columns=['Skin_Fold'])
# Out:
#      Pregnant  Glucose  Diastolic_BP  Serum_Insulin   BMI  Diabetes_Pedigree  \
# 0           6    148.0          72.0            NaN  33.6              0.627
# 1           1     85.0          66.0            NaN  26.6              0.351
# 2           8    183.0          64.0            NaN  23.3              0.672
# 3           1     89.0          66.0           94.0  28.1              0.167
# 4           0    137.0          40.0          168.0  43.1              2.288
# ..        ...      ...           ...            ...   ...                ...
# 763        10    101.0          76.0          180.0  32.9              0.171
# 764         2    122.0          70.0            NaN  36.8              0.340
# 765         5    121.0          72.0          112.0  26.2              0.245
# 766         1    126.0          60.0            NaN  30.1              0.349
# 767         1     93.0          70.0            NaN  30.4              0.315
#
#      Age  Class
# 0     50      1
# ...

# %%
df.fillna(method='bfill')
# Out:
# /tmp/ipython-input-2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0           94.0  33.6
# 1           1     85.0          66.0       29.0           94.0  26.6
# 2           8    183.0          64.0       23.0           94.0  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0          112.0  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0       31.0            NaN  30.1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64
